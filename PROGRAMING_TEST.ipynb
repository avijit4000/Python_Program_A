# %%
import pandas as pd

# %%
df=pd.read_csv("D:\Pyn\MSDSM\SEMESTER_1\Programing\BSE Sensex Daily Close Jan1990 Oct2020.csv")

# %%
df.head()
# Out:
#         Date  Open  High  Low   Close
# 0  01-Jan-90   NaN   NaN  NaN  783.35
# 1  02-Jan-90   NaN   NaN  NaN  780.01
# 2  03-Jan-90   NaN   NaN  NaN  763.22
# 3  04-Jan-90   NaN   NaN  NaN  760.80
# 4  05-Jan-90   NaN   NaN  NaN  774.58

# %%
df.tail()
# Out:
#            Date      Open      High       Low     Close
# 7416  13-Oct-20  40592.54  40786.82  40461.97  40625.51
# 7417  14-Oct-20  40623.19  40880.25  40279.55  40794.74
# 7418  15-Oct-20  41048.05  41048.05  39667.47  39728.41
# 7419  16-Oct-20  39936.61  40125.71  39699.42  39982.98
# 7420  19-Oct-20  40318.57  40519.48  40211.22  40431.60

# %%
df.shape
# Out:
# (7421, 5)

# %%
price=df['Close']

# %%
l=[]
for i in price:
    l.append(i)

# %%
len(l)
# Out:
# 7421

# %%
print(l)
# Out:
# [783.35, 780.01, 763.22, 760.8, 774.58, 778.33, 774.5, 782.48, 780.34, 763.55, 755.58, 745.19, 738.58, 710.75, 706.85, 722.01, 718.95, 716.23, 701.08, 683.32, 692.41, 684.48, 674.26, 674.47, 659.3, 673.27, 673.26, 679.29, 690.07, 689.98, 679.53, 674.47, 678.57, 678.97, 680.58, 676.23, 692.58, 691.61, 685.88, 678.7, 678.38, 670.38, 673.94, 688.08, 683.47, 678.91, 686.29, 711.04, 726.31, 721.69, 738.22, 757.76, 761.33, 770.3, 767.74, 781.05, 782.97, 805.86, 794.44, 770.74, 769.97, 781.17, 748.79, 755.58, 773.76, 759.15, 787.36, 792.57, 791.79, 793.58, 795.13, 786.21, 779.22, 776.11, 779.38, 785.19, 779.5, 780.73, 774.75, 786.9, 770.36, 767.02, 780.3, 777.96, 788.14, 786.08, 787.1, 810.15, 811.59, 803.89, 800.8, 799.5, 797.61, 795.11, 794.18, 790.03, 794.7, 787.36, 781.66, 783.21, 785.75, 791.32, 790.76, 790.31, 800.3, 814.72, 817.54, 820.35, 829.47, 834.49, 850.5, 862.88, 883.03, 896.25, 896.16, 893.08, 909.3, 924.29, 920.24, 886.33, 916.93, 926.92, 941.7, 940.73, 1007.97, 1008.12, 103
# ...

# %%
m=[]
for j in price:
    m.append(int(j))

# %%
print(m)
# Out:
# [783, 780, 763, 760, 774, 778, 774, 782, 780, 763, 755, 745, 738, 710, 706, 722, 718, 716, 701, 683, 692, 684, 674, 674, 659, 673, 673, 679, 690, 689, 679, 674, 678, 678, 680, 676, 692, 691, 685, 678, 678, 670, 673, 688, 683, 678, 686, 711, 726, 721, 738, 757, 761, 770, 767, 781, 782, 805, 794, 770, 769, 781, 748, 755, 773, 759, 787, 792, 791, 793, 795, 786, 779, 776, 779, 785, 779, 780, 774, 786, 770, 767, 780, 777, 788, 786, 787, 810, 811, 803, 800, 799, 797, 795, 794, 790, 794, 787, 781, 783, 785, 791, 790, 790, 800, 814, 817, 820, 829, 834, 850, 862, 883, 896, 896, 893, 909, 924, 920, 886, 916, 926, 941, 940, 1007, 1008, 1033, 1098, 1061, 1043, 1010, 1025, 1046, 1092, 1088, 1080, 1096, 1134, 1157, 1151, 1217, 1207, 1197, 1247, 1260, 1201, 1200, 1229, 1255, 1282, 1321, 1286, 1228, 1314, 1332, 1331, 1389, 1466, 1404, 1420, 1426, 1559, 1472, 1402, 1280, 1311, 1223, 1299, 1269, 1295, 1323, 1331, 1381, 1412, 1392, 1293, 1308, 1320, 1265, 1241, 1304, 1327, 1284, 1208, 1196, 1203, 1163,
# ...

# %%
import seaborn as sns

# %%
sns.boxplot(m)
# Out:
# <Axes: >

# %%
r=open("price","w")

# %%
r.write(m)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 r.write(m)
#
# TypeError: write() argument must be str, not list

# %%
nums=[5,6,10,11,10,9,7,20,21,18,16,10]
max_sum = 0

selected_numbers = []
for i in range(len(nums)):
    for j in range(i + 1, len(nums)):
        diff = abs(nums[i] - nums[j])
        current_sum = nums[i] + nums[j] - diff
        if current_sum > max_sum:
            max_sum = current_sum
            selected_numbers = [nums[i], nums[j]]
print( selected_numbers)

# Input a list of numbers
# num_list = [float(x) for x in input("Enter a list of numbers separated by spaces: ").split()]
#
# result_numbers = find_numbers_with_maximum_difference_sum(num_list)
# print("List of two numbers with maximum difference addition:", result_numbers)
# Out:
# [20, 21]

# %%
nums=[5,6,10,11,10,9,7,20,21,18,16,10]
max_sum = 0
selected_numbers = []
for i in range(len(nums)):
    for j in range(i + 1, len(nums)):
        diff = abs(nums[i] - nums[j])
        current_sum = nums[i] + nums[j] - diff
        if current_sum > max_sum:
            max_sum = current_sum
            selected_numbers = [nums[i], nums[j]]
print( selected_numbers)
# Out:
# [20, 21]

# %%
mylist=[5,8,9,6,3]
l=len(mylist)
print(l)
for i in range (l):
    for j in range(i+1,l):
        if mylist[j]<mylist[i]:
            mylist[i],mylist[j]=mylist[j],mylist[i]
print(mylist)
# Out:
# 5
# [3, 5, 6, 8, 9]

# %%
def add(x,y):
    print(x+y)
add(8,5)
# Out:
# 13

# %%
def add(x,y):
    return x+y
add(8,5)
# Out:
# 13

# %%
def add(x,y):
    print(x+y)
print(add(8,5))
# Out:
# 13
# None

# %%
mylist = [2,5,7,5,3,4,5,2]
ass = []
while mylist:
    minimum = mylist[0]
    for i in mylist:
        if i < minimum:
            minimum = i
    ass.append(minimum)
    mylist.remove(minimum)
print(ass)
# Out:
# [2, 2, 3, 4, 5, 5, 5, 7]

# %%
mylist= [5,6,10,11,10,9,7,20,21,18,16,10]
ass = []
while mylist:
    minimum = mylist[0]
    for i in mylist:
        if i > minimum:
            for j in range(len(mylist)):
                minimum = i
    ass.append(minimum)
    mylist.remove(minimum)
print(ass)
# Out:
# [21, 20, 18, 16, 11, 10, 10, 10, 9, 7, 6, 5]

# %%
def maxProfit(price, start, end):

    # If the stocks can't be bought
    if (end <= start):
        return 0
    # Initialise the profit
    profit = 0
    # The day at which the stock
    # must be bought
    for i in range(start, end, 1):
        # The day at which the
        # stock must be sold
        for j in range(i+1, end+1):

            # If buying the stock at ith day and
            # selling it at jth day is profitable
            if (price[j] > price[i]):

                # Update the current profit
                curr_profit = price[j] - price[i] +\
                    maxProfit(price, start, i - 1) + \
                    maxProfit(price, j + 1, end)

                # Update the maximum profit so far
                profit = max(profit, curr_profit)

    return profit
if __name__ == '__main__':
    price = [100, 180, 260, 310, 40, 535, 695]
    n = len(price)

    print(maxProfit(price, 0, n - 1))
# Out:
# 865

# %%
def maxProfit(price, start, end):
    if (end <= start):
        return 0
    profit = 0
    for i in range(start, end, 1):
        for j in range(i+1, end+1):
            if (price[j] > price[i]):
                curr_profit = price[j] - price[i] +\
                    maxProfit(price, start, i - 1) + \
                    maxProfit(price, j + 1, end)
                profit = max(profit, curr_profit)
    return profit

# %%
if __name__ == '__main__':
    price = [100, 180, 260, 310, 40, 535, 695]
    n = len(price)

    print(maxProfit(price, 0, n - 1))
# Out:
# 865

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close'], dtype='object')

# %%
df_1=df["Close"]

# %%
df_1.shape
# Out:
# (7421,)

# %%
df_1.head()
# Out:
# 0    783.35
# 1    780.01
# 2    763.22
# 3    760.80
# 4    774.58
# Name: Close, dtype: float64

# %%
m=[]
for i in df_1:
    m.append(i)

# %%
print(m)
# Out:
# [783.35, 780.01, 763.22, 760.8, 774.58, 778.33, 774.5, 782.48, 780.34, 763.55, 755.58, 745.19, 738.58, 710.75, 706.85, 722.01, 718.95, 716.23, 701.08, 683.32, 692.41, 684.48, 674.26, 674.47, 659.3, 673.27, 673.26, 679.29, 690.07, 689.98, 679.53, 674.47, 678.57, 678.97, 680.58, 676.23, 692.58, 691.61, 685.88, 678.7, 678.38, 670.38, 673.94, 688.08, 683.47, 678.91, 686.29, 711.04, 726.31, 721.69, 738.22, 757.76, 761.33, 770.3, 767.74, 781.05, 782.97, 805.86, 794.44, 770.74, 769.97, 781.17, 748.79, 755.58, 773.76, 759.15, 787.36, 792.57, 791.79, 793.58, 795.13, 786.21, 779.22, 776.11, 779.38, 785.19, 779.5, 780.73, 774.75, 786.9, 770.36, 767.02, 780.3, 777.96, 788.14, 786.08, 787.1, 810.15, 811.59, 803.89, 800.8, 799.5, 797.61, 795.11, 794.18, 790.03, 794.7, 787.36, 781.66, 783.21, 785.75, 791.32, 790.76, 790.31, 800.3, 814.72, 817.54, 820.35, 829.47, 834.49, 850.5, 862.88, 883.03, 896.25, 896.16, 893.08, 909.3, 924.29, 920.24, 886.33, 916.93, 926.92, 941.7, 940.73, 1007.97, 1008.12, 103
# ...

# %%
if __name__ == '__main__':
    price = m
    n = len(price)
print(maxProfit(price, 0, n - 1))
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\ProgramData\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\aviji\AppData\Local\Temp\ipykernel_15324\3066070164.py", line 4, in <module>
#     print(maxProfit(price, 0, n - 1))
#   File "C:\Users\aviji\AppData\Local\Temp\ipykernel_15324\1893696358.py", line 10, in maxProfit
#     maxProfit(price, j + 1, end)
#   File "C:\Users\aviji\AppData\Local\Temp\ipykernel_15324\1893696358.py", line 10, in maxProfit
#     maxProfit(price, j + 1, end)
#   File "C:\Users\aviji\AppData\Local\Temp\ipykernel_15324\1893696358.py", line 10, in maxProfit
#     maxProfit(price, j + 1, end)
#   [Previous line repeated 357 more times]
#   File "C:\Users\aviji\AppData\Local\Temp\ipykernel_15324\1893696358.py", line 9, in maxProfit
# ...

# %%
def maxProfit(price, start, end):
    if (end <= start):
        return 0
    profit = 0
    for i in range(start, end, 1):
        for j in range(i+1, end+1):
            if (price[j] > price[i]):
                curr_profit = price[j] - price[i] +\
                    maxProfit(price, start, i - 1) + \
                    maxProfit(price, j + 1, end)
                profit = max(profit, curr_profit)
    return profit

# %%
# Python3 Program to find
# best buying and selling days

# This function finds the buy sell
# schedule for maximum profit


def stockBuySell(price, n):

	# Prices must be given for at least two days
	if (n == 1):
		return

	# Traverse through given price array
	i = 0
	while (i < (n - 1)):

		# Find Local Minima
		# Note that the limit is (n-2) as we are
		# comparing present element to the next element
		while ((i < (n - 1)) and (price[i + 1] <= price[i])):
			i += 1

		# If we reached the end, break
		# as no further solution possible
		if (i == n - 1):
			break

		# Store the index of minima
		buy = i
		i += 1

		# Find Local Maxima
		# Note that the limit is (n-1) as we are
		# comparing to previous element
		while ((i < n) and (price[i] >= price[i - 1])):
			i += 1

		# Store the index of maxima
		sell = i - 1

		print("Buy on day: ", buy, "\t",
			"Sell on day: ", sell)

# Driver code


# Stock prices on consecutive days
price = [100, 180, 260, 310, 40, 535, 695]
n = len(price)

# Function call
stockBuySell(price, n)
# Out:
# Buy on day:  0 	 Sell on day:  3
# Buy on day:  4 	 Sell on day:  6

# %%
# Python3 program for the above approach
def max_profit(prices: list, days: int) -> int:
	profit = 0
	for i in range(1, days): # checks if elements are adjacent and in increasing order
		if prices[i] > prices[i-1]: # difference added to 'profit'
			profit += prices[i] - prices[i-1]
	return profit
if __name__ == '__main__':
	# stock prices on consecutive days
	prices = [100, 180, 260, 310, 40, 535, 695]
	# function call
	profit = max_profit(prices, len(prices))
	print(profit)
# Out:
# 865

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7421 entries, 0 to 7420
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    7421 non-null   object
#  1   Open    7205 non-null   float64
#  2   High    7203 non-null   float64
#  3   Low     7203 non-null   float64
#  4   Close   7421 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 290.0+ KB

# %%
int(df_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 int(df_1)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\series.py:206, in _coerce_method.<locals>.wrapper(self)
#     204 if len(self) == 1:
#     205     return converter(self.iloc[0])
# --> 206 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'int'>
